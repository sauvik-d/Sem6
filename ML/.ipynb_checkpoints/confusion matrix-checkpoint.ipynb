# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spam_predictions.csv')

# %%
df
# Out:
#       actual predicted
# 0   not spam  not spam
# 1       spam      spam
# 2       spam  not spam
# 3       spam      spam
# 4       spam  not spam
# 5       spam      spam
# 6   not spam      spam
# 7       spam      spam
# 8   not spam  not spam
# 9   not spam      spam
# 10  not spam  not spam
# 11  not spam  not spam
# 12      spam  not spam
# 13  not spam      spam
# 14      spam      spam
# 15      spam      spam
# 16  not spam  not spam
# 17  not spam      spam
# 18      spam  not spam
# 19      spam      spam
# 20      spam  not spam
# 21      spam  not spam
# 22  not spam  not spam
# 23      spam      spam
# 24      spam      spam
# 25  not spam      spam
# 26  not spam      spam
# 27      spam      spam
# 28  not spam      spam
# 29      spam      spam
# 30      spam  not spam
# 31  not spam      spam
# 32      spam      spam
# 33  not spam      spam
# 34  not spam      spam
# 35      spam  not spam
# 36  not spam      spam
# 37      spam  not spam
# 38  not spam  not spam
# 39      spam  not spam
# 40      spam      spam
# 41  not spam      spam
# 42      spam      spam
# 43  not spam  not spam
# 44      spam      spam
# 45  not spam      spam
# 46  not spam      spam
# 47      spam      spam
# 48  not spam      spam
# 49      spam  not spam

# %%
tp = len(df[(df['actual'] == 'spam') & (df['predicted'] == 'spam')])
tp
# Out:
# 16

# %%
fp = len(df[(df['actual'] == 'not spam') & (df['predicted'] == 'spam')])
fp
# Out:
# 15

# %%
fn = len(df[(df['actual'] == 'spam') & (df['predicted'] == 'not spam')])
fn
# Out:
# 11

# %%
tn = len(df[(df['actual'] == 'not spam') & (df['predicted'] == 'not spam')])
tn
# Out:
# 8

# %%
confusion_matrix = np.array([[tp, fp], [fn, tn]])
confusion_matrix
# Out:
# array([[16, 15],
#        [11,  8]])
